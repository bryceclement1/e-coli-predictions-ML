# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Beach6_2019_calibration_data.csv')

# %%
df
# Out:
#           DATE  ECOLI_LOG10  TURB_NTRU  RHUM_PCT  WTEMP_CEL  BIRDS_NO  \
# 0    5/29/2014       0.6021     9.8100        79      15.44         0
# 1    5/30/2014       0.3010     3.2550        91      10.56         5
# 2    5/31/2014       0.3010     1.8950        73      16.83         0
# 3     6/1/2014       0.3010     1.9725        42       9.22         0
# 4     6/2/2014       1.0792     3.1425        64      10.56         1
# ..         ...          ...        ...       ...        ...       ...
# 458  8/29/2018       1.6021    18.2000        68      25.17         4
# 459  8/30/2018       1.9823    17.7500        65      23.44         0
# 460  8/31/2018       1.5051     1.9300        81      23.39         0
# 461   9/1/2018       1.3424     1.4500        79      23.72        77
# 462   9/2/2018       2.3424    18.6750        83      23.61         7
#
#      CHANGELL_FT  AirportWindSpInst_mph  AirportRain48W_in
# 0         -0.131                      6              0.075
# ...

# %%
raw_ecoli = 10 ** df['ECOLI_LOG10']
raw_ecoli
# Out:
# 0        4.000369
# 1        1.999862
# 2        1.999862
# 3        1.999862
# 4       12.000518
#           ...
# 458     40.003685
# 459     96.006359
# 460     31.996318
# 461     21.998851
# 462    219.988511
# Name: ECOLI_LOG10, Length: 463, dtype: float64

# %%
plt.hist(raw_ecoli, bins=20, edgecolor='black')
plt.xlabel("E-Coli Level")
plt.ylabel("Frequency")
plt.title("Distribution of Raw E-Coli Levels")
plt.show()

# %%
plt.hist(df['ECOLI_LOG10'], bins=20, edgecolor='black')
plt.xlabel("E-Coli Level")
plt.ylabel("Frequency")
plt.title("Distribution of Log10 E-Coli Levels")
plt.show()

# %%
plt.scatter(df['TURB_NTRU'], df['ECOLI_LOG10'])
plt.xlabel("Turbidity")
plt.ylabel("ECOLI_LOG10")
plt.title("Turbidity vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['TURB_NTRU'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.40777797338400407

# %%
Log10_Turbidity = np.log10(df['TURB_NTRU'])
plt.scatter(Log10_Turbidity, df['ECOLI_LOG10'])
plt.xlabel("Log10 Turbidity")
plt.ylabel("ECOLI_LOG10")
plt.title("Log10 Turbidity vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(Log10_Turbidity, df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.5509551885418595

# %%
plt.scatter(df['RHUM_PCT'], df['ECOLI_LOG10'])
plt.xlabel("Relative Humidity(%)")
plt.ylabel("ECOLI_LOG10")
plt.title("Relative Humidity vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['RHUM_PCT'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.2519169066699275

# %%
plt.scatter(df['WTEMP_CEL'], df['ECOLI_LOG10'])
plt.xlabel("Water Temperature(Celsius)")
plt.ylabel("ECOLI_LOG10")
plt.title("Water Temperature vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['WTEMP_CEL'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.2500755157076672

# %%
plt.scatter(df['BIRDS_NO'], df['ECOLI_LOG10'])
plt.xlabel("Number of Birds Spotted")
plt.ylabel("ECOLI_LOG10")
plt.title("Number of Birds vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['BIRDS_NO'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.12571441241566217

# %%
plt.scatter(df['CHANGELL_FT'], df['ECOLI_LOG10'])
plt.xlabel("24 Hour Lake Level Change(ft)")
plt.ylabel("ECOLI_LOG10")
plt.title("Lake Level Change vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['CHANGELL_FT'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.1757804323856089

# %%
plt.scatter(df['AirportWindSpInst_mph'], df['ECOLI_LOG10'])
plt.xlabel("Airport Wind Speed(mph)")
plt.ylabel("ECOLI_LOG10")
plt.title("Airport Wind Speed vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['AirportWindSpInst_mph'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.24027119187113832

# %%
plt.scatter(df['AirportRain48W_in'], df['ECOLI_LOG10'])
plt.xlabel("48 Hour Airport Rainfall(in)")
plt.ylabel("ECOLI_LOG10")
plt.title("Rainfall vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(df['AirportRain48W_in'], df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.2619355131142613

# %%
sqrt_rain = np.sqrt(df['AirportRain48W_in'])
plt.scatter(sqrt_rain, df['ECOLI_LOG10'])
plt.xlabel("48 Hour Airport Rainfall(in)")
plt.ylabel("ECOLI_LOG10")
plt.title("Rainfall vs. ECOLI_LOG10")
plt.show()
correlation_coefficient = np.corrcoef(sqrt_rain, df['ECOLI_LOG10'])
print(correlation_coefficient[0,1])
# Out:
# 0.36826447520538624
